# %% [markdown]
# ***DOMAIN:*** Smartphone, Electronics<br>
# ***CONTEXT:*** India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India
# in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by
# smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has
# made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they
# are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the
# right place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation system
# based on individual consumer’s behaviour or choice.

# %% [markdown]
# ***DATA DESCRIPTION:***<br>
# ***• author :*** name of the person who gave the rating<br>
# ***• country :*** country the person who gave the rating belongs to<br>
# ***• data :*** date of the rating<br>
# ***• domain:*** website from which the rating was taken from<br>
# ***• extract:*** rating content<br>
# ***• language:*** language in which the rating was given<br>
# ***• product:*** name of the product/mobile phone for which the rating was given<br>
# ***• score:*** average rating for the phone<br>
# ***• score_max:*** highest rating given for the phone<br>
# ***• source:*** source from where the rating was taken<br>

# %% [markdown]
# **PROJECT OBJECTIVE:** We will build a recommendation system using popularity based and collaborative filtering methods to recommend mobile phones to a user which are most popular and personalised respectively..

# %% [markdown]
# **1. Import the necessary libraries and read the provided CSVs as a data frame**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %% [markdown]
# ***Merge the provided CSVs into one data-frame.***

# %%
csv_file_list = ["phone_user_review_file_1.csv", "phone_user_review_file_2.csv","phone_user_review_file_3.csv","phone_user_review_file_4.csv","phone_user_review_file_5.csv","phone_user_review_file_6.csv"]

list_of_dataframes = []
for filename in csv_file_list:
    print(filename)
    list_of_dataframes.append(pd.read_csv(filename,encoding='latin1'))

phones_df = pd.concat(list_of_dataframes)
# Out:
# phone_user_review_file_1.csv
# phone_user_review_file_2.csv
# phone_user_review_file_3.csv
# phone_user_review_file_4.csv
# phone_user_review_file_5.csv
# phone_user_review_file_6.csv

# %% [markdown]
# ***Check a few observations and shape of the data-frame***

# %%
phones_df.head()
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# 2           amazon.com    6.0       10.0
# 3          samsung.com    9.2       10.0
# 4  verizonwireless.com    4.0       10.0
#
#                                              extract       author  \
# 0  As a diehard Samsung fan who has had every Sam...   CarolAnn35
# 1  Love the phone. the phone is sleek and smooth ...    james0923
# 2  Adequate feel. Nice heft. Processor's still sl...     R. Craig
# 3  Never disappointed. One of the reasons I've be...  Buster2020
# 4  I've now found that i'm in a group of people t...   S Ate Mine
#
#                                              product
# 0                                  Samsung Galaxy S8
# 1                                  Samsung Galaxy S8
# 2  Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                      Samsung Galaxy S8 64GB (AT&T)
# 4                                  Samsung Galaxy S8

# %%
row,col = phones_df.shape
print("Number of rows: {}".format(row))
print("Number of columns: {}".format(col))
# Out:
# Number of rows: 1415133
# Number of columns: 11

# %%
phones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %%
phones_df.isna().sum()
# Out:
# phone_url        0
# date             0
# lang             0
# country          0
# source           0
# domain           0
# score        63489
# score_max    63489
# extract      19361
# author       63202
# product          1
# dtype: int64

# %% [markdown]
# There are few NA's in score, score_max, extract and author columns. Dropping off the records having NA's

# %%
phones_cl = phones_df.dropna()

# %% [markdown]
# ***Round off scores to the nearest integers.***

# %%
phones_cl.loc[:, ('score', 'score_max')]
# Out:
#         score  score_max
# 0        10.0       10.0
# 1        10.0       10.0
# 2         6.0       10.0
# 3         9.2       10.0
# 4         4.0       10.0
# ...       ...        ...
# 163832    2.0       10.0
# 163833   10.0       10.0
# 163834    2.0       10.0
# 163835    8.0       10.0
# 163836    2.0       10.0
#
# [1275917 rows x 2 columns]

# %%
phones_cl.loc[:, ('score', 'score_max')] = phones_cl.loc[:, ('score', 'score_max')].round()
# Out:
# D:\Installed_Softwares\Anaconda3\lib\site-packages\pandas\core\indexing.py:1717: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)

# %% [markdown]
# ***Check for missing values. Impute the missing values if there is any***<br>
# MIssing values are dropped as the number of records are 63000+ out of 1400000 records.

# %% [markdown]
# ***Check for duplicate values and remove them if there is any.***

# %%
phones_cl.drop_duplicates()
# Out:
#                                 phone_url       date lang country  \
# 0          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 1          /cellphones/samsung-galaxy-s8/  4/28/2017   en      us
# 2          /cellphones/samsung-galaxy-s8/   5/4/2017   en      us
# 3          /cellphones/samsung-galaxy-s8/   5/2/2017   en      us
# 4          /cellphones/samsung-galaxy-s8/  5/11/2017   en      us
# ...                                   ...        ...  ...     ...
# 163832  /cellphones/alcatel-ot-club_1187/  5/12/2000   de      de
# 163833  /cellphones/alcatel-ot-club_1187/  5/11/2000   de      de
# 163834  /cellphones/alcatel-ot-club_1187/   5/4/2000   de      de
# 163835  /cellphones/alcatel-ot-club_1187/   5/1/2000   de      de
# 163836  /cellphones/alcatel-ot-club_1187/  4/25/2000   de      de
#
#                   source               domain  score  score_max  \
# 0       Verizon Wireless  verizonwireless.com   10.0       10.0
# 1            Phone Arena       phonearena.com   10.0       10.0
# 2                 Amazon           amazon.com    6.0       10.0
# 3                Samsung          samsung.com    9.0       10.0
# 4       Verizon Wireless  verizonwireless.com    4.0       10.0
# ...                  ...                  ...    ...        ...
# 163832              Ciao              ciao.de    2.0       10.0
# 163833              Ciao              ciao.de   10.0       10.0
# 163834              Ciao              ciao.de    2.0       10.0
# 163835              Ciao              ciao.de    8.0       10.0
# 163836              Ciao              ciao.de    2.0       10.0
#
#                                                   extract        author  \
# 0       As a diehard Samsung fan who has had every Sam...    CarolAnn35
# 1       Love the phone. the phone is sleek and smooth ...     james0923
# 2       Adequate feel. Nice heft. Processor's still sl...      R. Craig
# 3       Never disappointed. One of the reasons I've be...   Buster2020
# 4       I've now found that i'm in a group of people t...    S Ate Mine
# ...                                                   ...           ...
# 163832  Weil mein Onkel bei ALcatel arbeitet habe ich ...    david.paul
# 163833  Hy Liebe Leserinnen und Leser!! Ich habe seit ...  Christiane14
# 163834  Jetzt hat wohl Alcatell gedacht ,sie machen wa...    michaelawr
# 163835  Ich bin seit 2 Jahren (stolzer) Besitzer eines...   claudia0815
# 163836  Was sich Alkatel hier wieder ausgedacht hat,sc...    michaelawr
#
#                                                   product
# 0                                       Samsung Galaxy S8
# 1                                       Samsung Galaxy S8
# 2       Samsung Galaxy S8 (64GB) G950U 5.8" 4G LTE Unl...
# 3                           Samsung Galaxy S8 64GB (AT&T)
# 4                                       Samsung Galaxy S8
# ...                                                   ...
# 163832                            Alcatel Club Plus Handy
# 163833                            Alcatel Club Plus Handy
# 163834                            Alcatel Club Plus Handy
# 163835                            Alcatel Club Plus Handy
# 163836                            Alcatel Club Plus Handy
#
# [1271437 rows x 11 columns]

# %% [markdown]
# 4500+ records has been removed as duplicates.

# %% [markdown]
# ***Keep only 1000000 data samples. Use random state=612.***<br>
# 80% of the data has to be taken after clean up to keep 1000000 records.

# %%
phones_sampled = phones_cl.sample(n=1000000,random_state=612)

# %% [markdown]
# ***Drop irrelevant features. Keep features like Author, Product, and Score***

# %%
phones_fl = phones_sampled[['author','product','score']]

# %%
phones_fl.head(5)
# Out:
#                    author                                            product  \
# 292711  Giuseppe Calavaro  Alcatel One Touch 20-04G Telefono Cellulare, Nero
# 78482           Buraian22                                        Huawei M750
# 126183     badamyan.karen                                        Nokia C7-00
# 32139     Amazon Customer  Binatone SM800 Touch Screen Big Button Sim Fre...
# 17325             unknown               Samsung Samsung Galaxy A5 2016 - Wit
#
#         score
# 292711    6.0
# 78482     2.0
# 126183   10.0
# 32139    10.0
# 17325     6.0

# %% [markdown]
# ***Identify the most rated features***

# %%
phones_fl[phones_fl['score'].values == phones_fl['score'].median()]
# Out:
#                 author                                            product  \
# 86389           Petras                                   Samsung SGH-X700
# 149640       BruceDude                                                S46
# 160977          pklat   Samsung GALAXY A3 (2016) A310F white Android S...
# 85798            J.R90               Samsung Galaxy S6 edge zwart / 32 GB
# 107910     Maris123654                    Samsung Galaxy S6 zwart / 32 GB
# ...                ...                                                ...
# 14503      nixter1029               Samsung Galaxy S7 edge 32GB (Verizon)
# 81273   Peter Janssens                                Sony Xperia Go Geel
# 76059      Selina-1991    Samsung Galaxy Note 3 zwart / 32 GB - Overzicht
# 114166             EdH                            Huawei P8 grijs / 16 GB
# 109032          Rengel                    Samsung Galaxy S6 zwart / 32 GB
#
#         score
# 86389     9.0
# 149640    9.0
# 160977    9.0
# 85798     9.0
# 107910    9.0
# ...       ...
# 14503     9.0
# 81273     9.0
# 76059     9.0
# 114166    9.0
# 109032    9.0
#
# [30233 rows x 3 columns]

# %% [markdown]
# ***Identify the users with most number of reviews.***

# %%
phones_fl[['author','score']].groupby(by='author',axis=0,sort=False).count().sort_values('score',ascending=False).head(10)
# Out:
#                  score
# author
# Amazon Customer  60237
# Cliente Amazon   15034
# e-bit             6865
# Client d'Amazon   5963
# Amazon Kunde      3691
# einer Kundin      2054
# Anonymous         2048
# einem Kunden      1493
# unknown           1357
# Anonymous         1151

# %% [markdown]
# ***Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final
# dataset.***

# %%
phones_fl.groupby(by=['product'],axis=0).count()>50
# Out:
#                                                     author  score
# product
# 'Smartphone Meizu Pro 5, 5,7 pouces avec Exynos...   False  False
# 'Sony Xperia X (F5122) â White â Dual Sim (...   False  False
# 'Sony Xperia X (F5122) â rosa â Dual Sim (G...   False  False
# (CUBOT) GT88 5.5" qHD 1.3GHz MTK6572 2-Core And...   False  False
# (DG300 Versione Aggiornata)5'' DOOGEE VOYAGER2 ...   False  False
# ...                                                    ...    ...
# Ø³Ø§Ù
# Ø³ÙÙØ¬ Ø¬Ø§ÙÙØ³Ù J1 2016 SM-J120H - ...   False  False
# Ø³Ø§Ù
# Ø³ÙÙØ¬ Ø¬Ø§ÙÙØ³Ù J1 2016 SM-J120H - ...   False  False
# Ø³Ø§Ù
# Ø³ÙÙØ¬ Ø¬Ø§ÙÙØ³Ù J1 SM-J120FD Ø¨Ø´Ø±...   False  False
# Ø³Ø§Ù
# Ø³ÙÙØ¬ Ø¬Ø§ÙÙØ³Ù J1 SM-J120FD Ø¨Ø´Ø±...   False  False
# æ©æç½æ C168i                                   False  False
#
# [51961 rows x 2 columns]

# %% [markdown]
# ***51961 products are having rating more than 50****

# %%
phones_fl.groupby(by=['author'],axis=0).count()>50
# Out:
#                                                     product  score
# author
#  efef                                                 False  False
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!                          False  False
# !!!JOSE"ANTONIO"                                      False  False
# !!:. PuNi$heR .:!!                                    False  False
# !&#34;Â§                                              False  False
# ...                                                     ...    ...
# æ­¦è¡å¤§å¸«                                          False  False
# ç«è¯ããªã§                                       False  False
# è¥ççç                                          False  False
# éº¦ç¬ç¬,                                            False  False
# ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ Xï¿½ï¿½ ï¿½ï¿½ï¿½ï¿...    False  False
#
# [625104 rows x 2 columns]

# %% [markdown]
# ***625104 users has given more than 50 rating***

# %% [markdown]
# ***Build a popularity based model and recommend top 5 mobile phones.***

# %%
phones_fl.groupby('product')['score'].mean().sort_values(ascending=False).head(5)
# Out:
# product
# æ©æç½æ C168i                                                                                                                        10.0
# Samsung Galaxy S7 32GB SAMSUNG Galaxy S7 32GB - Vit                                                                                       10.0
# HTC Butterfly S 901s Gray 16GB Factory Unlocked SmartPhone GSM 850 / 900 / 1800 / 1900 HSDPA 850 / 900 / 1900 / 2100                      10.0
# Samsung Galaxy S6 edge SM-G925F 128GB 4G Green - smartphones (Single SIM, Android, NanoSIM, GSM, HSPA, LTE)                               10.0
# Samsung Galaxy S6 edge SM-G925F - Smartphone de 5.1" (12,954 cm, 2560 x 1440 pixeles, SAMOLED, 2,1 GHz, 1,5 GHz, 3072 MB), color verde    10.0
# Name: score, dtype: float64

# %% [markdown]
# ***Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you
# can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You
# can try both user-based and item-based model.***

# %% [markdown]
# ***Taking 5000 rows only***

# %%
svd_input = phones_fl.sample(n=5000,random_state=612)

# %%
svd_input.shape[0]
# Out:
# 5000

# %%
svd_input.drop_duplicates(inplace=True)

# %%
svd_input = svd_input.sort_values('score').drop_duplicates(subset=['product','author'],keep='last')

# %%
svd_input['product'].value_counts().count()
# Out:
# 3765

# %%
svd_input['author'].value_counts().count()
# Out:
# 4332

# %%
svd_input.set_index('product')
# Out:
#                                                               author  score
# product
# Palm Pre                                                       Tommy    1.0
# C61                                                     cokeacola644    1.0
# Rumor / Scoop / UX-260                                 in2theunknown    1.0
# T-Mobile MDA Vario II                                           Gast    1.0
# SGH-D415 / SGH-D410                                      extremebase    1.0
# ...                                                              ...    ...
# Samsung Galaxy S5 SM-G900T 4G LTE 16GB Smartpho...            Jacamo   10.0
# Samsung Galaxy Core Plus Smartphone (10,9 cm (4...    Karlheinz Hame   10.0
# Samsung Galaxy Alpha (11,90 cm (4,7 Zoll) Super...           KÃ¤ufer   10.0
# Ð¢ÐµÐ»ÐµÑÐ¾Ð½ LG E960 Google Nexus 4 Black         ÐÑÐ¸ÑÑÐ¸Ð½Ð°   10.0
# Samsung C3520I Telefono Cellulare, Argento [Ita...           Roberta   10.0
#
# [4868 rows x 2 columns]

# %%
score_mat = svd_input.pivot(index='product',columns='author',values='score')

# %%
normalised_mat = score_mat - np.asarray([(np.mean(score_mat, 1))]).T

# %%
np.sqrt(score_mat.shape[0] - 1)
# Out:
# 61.35144660071187

# %%
A = normalised_mat.T / np.sqrt(score_mat.shape[0] - 1)

# %%
A
# Out:
# product                                             **** PacK Exclusif A&d COFFRET WIKO **** Housse WIKO CINK FIVE Coque wiko cink five protection flip cover wiko...  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             1006  \
# author
# *Darkest*Star*                                       NaN
# //@ndzo                                              NaN
# 03102255mvp                                          NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                        NaN
# 19Dennis87                                           NaN
# ...                                                  ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                    NaN
# ÑÐ»Ñ                                               NaN
# ×ª×××¨ ×¨×¢××ª                                    NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...   NaN
# ãã¢ã ãã¦ãªã·ãª                            NaN
#
# product                                             2014 Newest DOOGEE DAGGER DG550 5.5'' Unlocked Octa Core 1.7Ghz Android 4.2.9 OS 3G Smartphone -- 5-Point-Touch...  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             3100 / 3120  \
# author
# *Darkest*Star*                                              NaN
# //@ndzo                                                     NaN
# 03102255mvp                                                 NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                               NaN
# 19Dennis87                                                  NaN
# ...                                                         ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                           NaN
# ÑÐ»Ñ                                                      NaN
# ×ª×××¨ ×¨×¢××ª                                           NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...          NaN
# ãã¢ã ãã¦ãªã·ãª                                   NaN
#
# product                                             5-Zoll- Android 4.2 Cubot P9 3G Smart Phone MTK6572 Dual Core 1.3GHz QHD IPS Schirm 512MB RAM 4GB ROM GPS 8MP...  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             5.5-Inch Unlocked Lenovo A850 3G Smartphone-(960x540) Quad Core 4GB MT6582m 1331MHz Android 4.2 Dual Camera +Dual SIM -Black (Rooted + Google Play)  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             6555  7290  8801 / 8800  \
# author
# *Darkest*Star*                                       NaN   NaN          NaN
# //@ndzo                                              NaN   NaN          NaN
# 03102255mvp                                          NaN   NaN          NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                        NaN   NaN          NaN
# 19Dennis87                                           NaN   NaN          NaN
# ...                                                  ...   ...          ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                    NaN   NaN          NaN
# ÑÐ»Ñ                                               NaN   NaN          NaN
# ×ª×××¨ ×¨×¢××ª                                    NaN   NaN          NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...   NaN   NaN          NaN
# ãã¢ã ãã¦ãªã·ãª                            NaN   NaN          NaN
#
# product                                             ?????????????? ?????????????? Samsung E2202 Black  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             ...  \
# author                                              ...
# *Darkest*Star*                                      ...
# //@ndzo                                             ...
# 03102255mvp                                         ...
# 100Ð¿ÑÐ´Ð¾Ð²                                       ...
# 19Dennis87                                          ...
# ...                                                 ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                   ...
# ÑÐ»Ñ                                              ...
# ×ª×××¨ ×¨×¢××ª                                   ...
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...  ...
# ãã¢ã ãã¦ãªã·ãª                           ...
#
# product                                             Ð¡Ð¾ÑÐ¾Ð²ÑÐ¹ ÑÐµÐ»ÐµÑÐ¾Ð½ Sonim XP 3300 Force  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             Ð¡Ð¾ÑÐ¾Ð²ÑÐ¹ ÑÐµÐ»ÐµÑÐ¾Ð½ Sony Xperia Tipo Dual ST21i2  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             Ð¢ÐµÐ»ÐµÑÐ¾Ð½ LG E960 Google Nexus 4 Black  \
# author
# *Darkest*Star*                                                                              NaN
# //@ndzo                                                                                     NaN
# 03102255mvp                                                                                 NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                               NaN
# 19Dennis87                                                                                  NaN
# ...                                                                                         ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                           NaN
# ÑÐ»Ñ                                                                                      NaN
# ×ª×××¨ ×¨×¢××ª                                                                           NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                          NaN
# ãã¢ã ãã¦ãªã·ãª                                                                   NaN
#
# product                                             ×××¤×× ×¡××××¨× Apple iPhone 7 Plus 32GB SimFree  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             ×××¤×× ×¡××××¨× G4 H815 ×× ×¢××¨ LG  \
# author
# *Darkest*Star*                                                                                 NaN
# //@ndzo                                                                                        NaN
# 03102255mvp                                                                                    NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                  NaN
# 19Dennis87                                                                                     NaN
# ...                                                                                            ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                              NaN
# ÑÐ»Ñ                                                                                         NaN
# ×ª×××¨ ×¨×¢××ª                                                                              NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                             NaN
# ãã¢ã ãã¦ãªã·ãª                                                                      NaN
#
# product                                             ×××¤×× ×¡××××¨× LG Nexus 5 16GB D821  \
# author
# *Darkest*Star*                                                                               NaN
# //@ndzo                                                                                      NaN
# 03102255mvp                                                                                  NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                NaN
# 19Dennis87                                                                                   NaN
# ...                                                                                          ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                            NaN
# ÑÐ»Ñ                                                                                       NaN
# ×ª×××¨ ×¨×¢××ª                                                                            NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                           NaN
# ãã¢ã ãã¦ãªã·ãª                                                                    NaN
#
# product                                             ×××¤×× ×¡××××¨× Meizu M3 Note 16GB  \
# author
# *Darkest*Star*                                                                             NaN
# //@ndzo                                                                                    NaN
# 03102255mvp                                                                                NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                              NaN
# 19Dennis87                                                                                 NaN
# ...                                                                                        ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                          NaN
# ÑÐ»Ñ                                                                                     NaN
# ×ª×××¨ ×¨×¢××ª                                                                          NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                         NaN
# ãã¢ã ãã¦ãªã·ãª                                                                  NaN
#
# product                                             ×××¤×× ×¡××××¨× Samsung Galaxy S6 Edge SM-G925F 64GB  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             ×××¤×× ×¡××××¨× Samsung Galaxy S6 SM-G920F 64GB  \
# author
# *Darkest*Star*                                                                                    NaN
# //@ndzo                                                                                           NaN
# 03102255mvp                                                                                       NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                     NaN
# 19Dennis87                                                                                        NaN
# ...                                                                                               ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                                 NaN
# ÑÐ»Ñ                                                                                            NaN
# ×ª×××¨ ×¨×¢××ª                                                                                 0.0
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                                NaN
# ãã¢ã ãã¦ãªã·ãª                                                                         NaN
#
# product                                             ×××¤×× ×¡××××¨× Xiaomi Redmi 4A 16GB
# author
# *Darkest*Star*                                                                               NaN
# //@ndzo                                                                                      NaN
# 03102255mvp                                                                                  NaN
# 100Ð¿ÑÐ´Ð¾Ð²                                                                                NaN
# 19Dennis87                                                                                   NaN
# ...                                                                                          ...
# ÑÐ¾Ð¿Ð¿Ð° ÑÑÐ°                                                                            NaN
# ÑÐ»Ñ                                                                                       NaN
# ×ª×××¨ ×¨×¢××ª                                                                            NaN
# â
#  Francis Mazzucco [Spain Premium Top Reviewe...                                           NaN
# ãã¢ã ãã¦ãªã·ãª                                                                    NaN
#
# [4332 rows x 3765 columns]

# %%
U, S, V = np.linalg.svd(A)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-57-cb3258f081fa> in <module>
# ----> 1 U, S, V = np.linalg.svd(A)
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# D:\Installed_Softwares\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1659
#    1660         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1661         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1662         u = u.astype(result_t, copy=False)
#    1663         s = s.astype(_realType(result_t), copy=False)
#
# D:\Installed_Softwares\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#      95
#      96 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 97     raise LinAlgError("SVD did not converge")
#      98
#      99 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge

# %%
phones_cl["lang"].value_counts()

# %%
demo_array = np.arange(10,21)
subset_demo_array = demo_array[0:7]
subset_demo_array[:]= 101
subset_demo_array
